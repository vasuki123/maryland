# %%
import pandas as pd  
import numpy as np  
import matplotlib as plt 
import seaborn as sns 
import os

# %%
df=pd.read_csv("C:/Users/vasuk/OneDrive/Desktop/traffic/Traffic_Violations2.csv", low_memory=False) 
df
# Out:
#         Date Of Stop Time Of Stop Agency  \
# 0          9/24/2013     17:11:00    MCP
# 1          8/29/2017     10:19:00    MCP
# 2          12/1/2014     12:52:00    MCP
# 3          8/29/2017      9:22:00    MCP
# 4          8/28/2017     23:41:00    MCP
# ...              ...          ...    ...
# 1048570    2/17/2014     12:02:00    MCP
# 1048571     6/5/2014     23:10:00    MCP
# 1048572     3/4/2014     20:07:00    MCP
# 1048573     2/1/2014     17:12:00    MCP
# 1048574    6/22/2014     14:26:00    MCP
#
#                                                SubAgency  \
# 0                            3rd district, Silver Spring
# 1                                 2nd district, Bethesda
# 2        6th district, Gaithersburg / Montgomery Village
# 3                            3rd district, Silver Spring
# 4        6th district, Gaithersburg / Montgomery Village
# ...                                                  ...
# 1048570                          1st district, Rockville
# ...

# %%
ColorResult =  df.groupby(['Color'])['Color'].count().sort_values(ascending=False)
print (ColorResult)
# Out:
# Color
# BLACK          213248
# SILVER         192710
# WHITE          161438
# GRAY           116642
# RED             82329
# BLUE            76098
# GREEN           38059
# GOLD            32667
# BLUE, DARK      22111
# TAN             21488
# MAROON          17629
# BLUE, LIGHT     13680
# BEIGE           11921
# GREEN, DK       11282
# GREEN, LGT       5729
# BROWN            4838
# YELLOW           3936
# ORANGE           3578
# BRONZE           2361
# PURPLE           2016
# MULTICOLOR        800
# CREAM             647
# COPPER            352
# PINK              144
# CHROME             22
# CAMOUFLAGE         20
# Name: Color, dtype: int64

# %%
ModelResult =  df.groupby(['Model'])['Model'].count().sort_values(ascending=False)
print (ModelResult)
# Out:
# Model
# 4S                116520
# TK                 66775
# ACCORD             38845
# CIVIC              36614
# CAMRY              35857
#                    ...
# CHEROKEE CHIEF         1
# RX 450 H               1
# CHEROKEE SPORT         1
# CHEROKEE SRT           1
# SCION X4               1
# Name: Model, Length: 14965, dtype: int64

# %%
df.notnull()
# Out:
#          Date Of Stop  Time Of Stop  Agency  SubAgency  Description  Location  \
# 0                True          True    True       True         True      True
# 1                True          True    True       True         True      True
# 2                True          True    True       True         True      True
# 3                True          True    True       True         True      True
# 4                True          True    True       True         True      True
# ...               ...           ...     ...        ...          ...       ...
# 1048570          True          True    True       True         True      True
# 1048571          True          True    True       True         True      True
# 1048572          True          True    True       True         True      True
# 1048573          True          True    True       True         True      True
# 1048574          True          True    True       True         True      True
#
# ...

# %%
matplotlib inline

# %%
df=pd.read_csv("C:/Users/vasuk/OneDrive/Desktop/traffic/Traffic_Violations2.csv", low_memory=False)
df.head(10)
# Out:
#   Date Of Stop Time Of Stop Agency  \
# 0    9/24/2013     17:11:00    MCP
# 1    8/29/2017     10:19:00    MCP
# 2    12/1/2014     12:52:00    MCP
# 3    8/29/2017      9:22:00    MCP
# 4    8/28/2017     23:41:00    MCP
# 5    8/27/2013      0:55:00    MCP
# 6    10/8/2013     13:23:00    MCP
# 7    4/24/2015      0:38:00    MCP
# 8    8/28/2017     23:41:00    MCP
# 9    8/28/2017     23:41:00    MCP
#
#                                          SubAgency  \
# 0                      3rd district, Silver Spring
# 1                           2nd district, Bethesda
# 2  6th district, Gaithersburg / Montgomery Village
# 3                      3rd district, Silver Spring
# 4  6th district, Gaithersburg / Montgomery Village
# 5                           2nd district, Bethesda
# 6                            4th district, Wheaton
# 7                          1st district, Rockville
# 8  6th district, Gaithersburg / Montgomery Village
# 9  6th district, Gaithersburg / Montgomery Village
#
# ...

# %%
df.tail(10)
# Out:
#         Date Of Stop Time Of Stop Agency                    SubAgency  \
# 1048565    3/17/2014     22:43:00    MCP      1st district, Rockville
# 1048566    4/12/2014      8:55:00    MCP  3rd district, Silver Spring
# 1048567    3/31/2014     18:01:00    MCP      1st district, Rockville
# 1048568     3/4/2014      9:16:00    MCP  3rd district, Silver Spring
# 1048569    4/16/2014     10:41:00    MCP        4th district, Wheaton
# 1048570    2/17/2014     12:02:00    MCP      1st district, Rockville
# 1048571     6/5/2014     23:10:00    MCP        4th district, Wheaton
# 1048572     3/4/2014     20:07:00    MCP     5th district, Germantown
# 1048573     2/1/2014     17:12:00    MCP     5th district, Germantown
# 1048574    6/22/2014     14:26:00    MCP  3rd district, Silver Spring
#
#                                                Description  \
# 1048565  FAILURE TO DISPLAY REGISTRATION CARD UPON DEMA...
# 1048566                  DRIVER CHANGING LANES WHEN UNSAFE
# ...

# %%
md=pd.read_csv("C:/Users/vasuk/OneDrive/Desktop/traffic/Traffic_Violations2.csv", low_memory=False) 
df.describe()
# Out:
#             Latitude      Longitude          Year
# count  975358.000000  975358.000000  1.041674e+06
# mean       39.072091     -77.101801  2.005680e+03
# std         1.174899       1.048180  8.803018e+01
# min       -94.610988    -151.255987  0.000000e+00
# 25%        39.031768     -77.193665  2.002000e+03
# 50%        39.072218     -77.093067  2.006000e+03
# 75%        39.137580     -77.044532  2.011000e+03
# max        41.543160      41.512073  9.999000e+03
